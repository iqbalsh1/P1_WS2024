# %% [markdown]
# ## pair0008:
# Abalone data: Abalones are marine snails

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
# Load dataset
df = pd.read_csv('datasets/pair0008.txt', delimiter=' ', header=None, names=['rings', 'height'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#    rings  height
# 0     15   0.095
# 1      7   0.090
# 2      9   0.135
# 3     10   0.125
# 4      7   0.080

# %%
# Scatter Plot
plt.scatter(df['rings'], df['height'])
plt.xlabel('rings')
plt.ylabel('height mm')
plt.title('Scatter plot of rings vs height')
plt.show()

# %% [markdown]
# "Rings" represent the no. of growth rings in the abalone's shell. It is used to estimate the age of the abalone i.e. by adding 1.5 to the number of rings.
# - Age (in years) = Rings + 1.5

# %%
# Plot the distribution of the data in both directions (x and y)
fig, axis = plt.subplots(1, 2, figsize=(16,6))

# Plot for rings -> height (X -> Y)
sns.histplot(df['rings'], kde=True, ax=axis[0])
axis[0].set_xlabel('rings')
axis[0].set_ylabel('height mm')
axis[0].set_title('rings distribution with KDE')

# Plot for rings -> height (Y -> X)
sns.histplot(df['height'], kde=True, ax=axis[1])
axis[1].set_xlabel('height mm')
axis[1].set_ylabel('rings')
axis[1].set_title('height distribution with KDE')

# Adjust layout to set the title and labels
plt.tight_layout()
plt.show()

# %%
# Dip-Test for x and y
dip_test, p_val = diptest(np.array(df['rings']))
print(f"Dip-Test (X → Y): {dip_test}, p-value: {p_val}")   
dip_test, p_val = diptest(np.array(df['height']))
print(f"Dip-Test (Y → X): {dip_test}, p-value: {p_val}")
# Out:
# Dip-Test (X → Y): 0.07589178836485516, p-value: 0.0
# Dip-Test (Y → X): 0.026334689968877185, p-value: 0.0

# %% [markdown]
# ### Findings:
# - The ground truth relationship is X → Y
# - The dip test results indicate potential multimodality in both directions (X → Y and Y → X).
# - Since p-values for both directions are zero, indicating that the distributions are not likely unimodal, suggesting **multimodality**.
