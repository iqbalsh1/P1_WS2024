# %% [markdown]
# ## pair0002:
# #### Weather Data from 349 DWD (Deutscher Wetterdienst) Stations

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
# Load dataset
df = pd.read_csv('datasets/pair0002.txt', delimiter=' ', header=None, names=['altitude', 'precipitation'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#    altitude  precipitation
# 0     205.0          828.3
# 1      46.0          791.5
# 2     794.0         1057.8
# 3     325.0          803.0
# 4     500.0         1252.2

# %%
# Scatter Plot
plt.scatter(df['altitude'], df['precipitation'])
plt.xlabel('altitude')
plt.ylabel('precipitation')
plt.title('Scatter plot (averaged over 1961-1990)')
plt.show()

# %%
# Plot the distribution of the data in both directions (x and y)
fig, axis = plt.subplots(1, 2, figsize=(16,6))

# Plot for altitude -> precipitation (X -> Y)
sns.histplot(df['altitude'], kde=True, ax=axis[0])
axis[0].set_xlabel('altitude')
axis[0].set_ylabel('precipitation')
axis[0].set_title('altitude distribution with KDE')

# Plot for altitude -> precipitation (Y -> X)
sns.histplot(df['precipitation'], kde=True, ax=axis[1])
axis[1].set_xlabel('precipitation')
axis[1].set_ylabel('altitude')
axis[1].set_title('precipitation distribution with KDE')

# Adjust layout to set the title and labels
plt.tight_layout()
plt.show()

# %%
# Dip-Test for x and y
dip_test, p_val = diptest(np.array(df['altitude']))
print(f"Dip-Test (X → Y): {dip_test}, p-value: {p_val}")   
dip_test, p_val = diptest(np.array(df['precipitation']))
print(f"Dip-Test (Y → X): {dip_test}, p-value: {p_val}")
# Out:
# Dip-Test (X → Y): 0.016086918254984987, p-value: 0.8264392785235934
# Dip-Test (Y → X): 0.013935920812711633, p-value: 0.9567947224188911

# %% [markdown]
# ### Findings:
# - The ground truth relationship is 𝑋 → 𝑌.
# - The dip test results show no multimodality in both direction (𝑋 → 𝑌 or 𝑌 → 𝑋 )
# - since both p-values are high, exhibiting that the distributions are likely **unimodal**.
