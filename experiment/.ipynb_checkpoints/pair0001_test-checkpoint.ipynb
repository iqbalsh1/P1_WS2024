# %% [markdown]
# ## pair0001:
# #### Weather Data from 349 DWD (Deutscher Wetterdienst) Stations

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
# Load dataset
df = pd.read_csv('datasets/pair0001.txt', delimiter=' ', header=None, names=['altitude', 'temperature'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#    altitude  temperature
# 0     205.0          9.7
# 1      46.0          8.2
# 2     794.0          6.4
# 3     325.0          8.1
# 4     500.0          6.2

# %%
# Scatter Plot
plt.scatter(df['altitude'], df['temperature'])
plt.xlabel('altitude')
plt.ylabel('temperature')
plt.title('Scatter plot (average over 1961-1990)')
plt.show()

# %%
# Plot the distribution of the data in both directions (x and y)
fig, axis = plt.subplots(1, 2, figsize=(16,6))

# Plot for altitude -> temperature (X -> Y)
sns.histplot(df['altitude'], kde=True, ax=axis[0])
axis[0].set_xlabel('altitude')
axis[0].set_ylabel('temperature')
axis[0].set_title('altitude distribution with KDE')

# Plot for altitude -> temperature (Y -> X)
sns.histplot(df['temperature'], kde=True, ax=axis[1])
axis[1].set_xlabel('temperature')
axis[1].set_ylabel('altitude')
axis[1].set_title('temperature distribution with KDE')

# Adjust layout to set the title and labels
plt.tight_layout()
plt.show()

# %%
# Dip-Test for x and y
dip_test, p_val = diptest(np.array(df['altitude']))
print(f"Dip-Test (X → Y): {dip_test}, p-value: {p_val}")   
dip_test, p_val = diptest(np.array(df['temperature']))
print(f"Dip-Test (Y → X): {dip_test}, p-value: {p_val}")
# Out:
# Dip-Test (X → Y): 0.016086918254984987, p-value: 0.8264392785235934
# Dip-Test (Y → X): 0.02148997134670487, p-value: 0.33236521433814703

# %% [markdown]
# ### Findings:
# - The ground truth relationship is X → Y.
# - The dip test results show no multimodality in both direction (X → Y or Y → X)
# - since both p-values are high, exhibiting that the distributions are likely **unimodal**.
