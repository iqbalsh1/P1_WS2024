# %% [markdown]
# ## pair0051:
#
# Daily mean values of ozone and temperature of year 2009 in Davos-See, Switzerland

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
# Load dataset
df = pd.read_csv('datasets/pair0051.txt', delimiter='\t', header=None, names=['ozone', 'temperature'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#    ozone  temperature
# 0   79.7         -5.3
# 1   76.7         -7.0
# 2   79.1         -9.2
# 3   76.0         -6.6
# 4   74.4         -9.1

# %%
# Scatter Plot
plt.scatter(df['ozone'], df['temperature'])
plt.xlabel('ozone (microgram / cubic meter)')
plt.ylabel('temperature (degree celsius)')
plt.title('Scatter plot of ozone vs temperature')
plt.show()

# %%
# Plot the distribution of the data in both directions (x and y)
fig, axis = plt.subplots(1, 2, figsize=(16,6))

# Plot for ozone -> temperature (X -> Y)
sns.histplot(df['ozone'], kde=True, ax=axis[0])
axis[0].set_xlabel('ozone')
axis[0].set_ylabel('temperature')
axis[0].set_title('ozone distribution with KDE')

# Plot for temperature -> ozone (Y -> X)
sns.histplot(df['temperature'], kde=True, ax=axis[1])
axis[1].set_xlabel('temperature')
axis[1].set_ylabel('ozone')
axis[1].set_title('temperature distribution with KDE')

# Adjust layout to set the title and labels
plt.tight_layout()
plt.show()

# %%
# Dip-Test for x and y
dip_test, p_val = diptest(np.array(df['ozone']))
print(f"Dip-Test (X → Y): {dip_test}, p-value: {p_val}")   
dip_test, p_val = diptest(np.array(df['temperature']))
print(f"Dip-Test (Y → X): {dip_test}, p-value: {p_val}")
# Out:
# Dip-Test (X → Y): 0.01326842522359337, p-value: 0.9686316268781707
# Dip-Test (Y → X): 0.021917808219178072, p-value: 0.2694402895161816

# %% [markdown]
# ### Findings:
# - The ground truth relationship is Y → X
# - Both directions (X → Y and Y → X) appear to have **unimodal** distributions, supported by high p-value.
