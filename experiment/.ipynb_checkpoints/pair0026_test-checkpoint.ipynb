# %% [markdown]
# ## pair0026:
# Concrete Compressive Strength

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
# Load dataset
df = pd.read_csv('datasets/pair0026.txt', delimiter=' ', header=None, names=['blast furnace slag', 'compressive strength'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#    blast furnace slag  compressive strength
# 0                 0.0                 79.99
# 1                 0.0                 61.89
# 2               142.5                 40.27
# 3               142.5                 41.05
# 4               132.4                 44.30

# %%
# Scatter Plot
plt.scatter(df['blast furnace slag'], df['compressive strength'])
plt.xlabel('blast furnace slag (kg in a m3 mixture )')
plt.ylabel('compressive strength (MPa)')
plt.title('Scatter plot of blast furnace slag vs compressive strength')
plt.show()

# %%
# Plot the distribution of the data in both directions (x and y)
fig, axis = plt.subplots(1, 2, figsize=(16,6))

# Plot for blast furnace slag -> compressive strength (X -> Y)
sns.histplot(df['blast furnace slag'], kde=True, ax=axis[0])
axis[0].set_xlabel('blast furnace slag')
axis[0].set_ylabel('compressive strength')
axis[0].set_title('blast furnace slag distribution with KDE')

# Plot for compressive strength -> blast furnace slag  (Y -> X)
sns.histplot(df['compressive strength'], kde=True, ax=axis[1])
axis[1].set_xlabel('compressive strength')
axis[1].set_ylabel('blast furnace slag')
axis[1].set_title('compressive strength distribution with KDE')

# Adjust layout to set the title and labels
plt.tight_layout()
plt.show()

# %%
# Dip-Test for x and y
dip_test, p_val = diptest(np.array(df['blast furnace slag']))
print(f"Dip-Test (X → Y): {dip_test}, p-value: {p_val}")   
dip_test, p_val = diptest(np.array(df['compressive strength']))
print(f"Dip-Test (Y → X): {dip_test}, p-value: {p_val}")
# Out:
# Dip-Test (X → Y): 0.050548150251740885, p-value: 0.0
# Dip-Test (Y → X): 0.011162596842208541, p-value: 0.5682147471819841

# %% [markdown]
# ### Findings:
# - The ground truth relationship is X → Y
# - The dip test results suggest that the distribution of X → Y is likely **multimodal**, supported by a low p-value 0.
# - While the distribution of Y → X direction is **unimodal**, supported by a high p-value 0.56.
