# %% [markdown]
# ## pair0034:
# BUPA liver disorders

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
# Load dataset
df = pd.read_csv('datasets/pair0034.txt', delimiter=' ', header=None, names=['drinks', 'alkphos'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#    drinks  alkphos
# 0     0.0       92
# 1     0.0       64
# 2     0.0       54
# 3     0.0       78
# 4     0.0       70

# %%
# Scatter Plot
plt.scatter(df['drinks'], df['alkphos'])
plt.xlabel('drinks (half-pint per day)')
plt.ylabel('alkphos (alkaline phosphotase)')
plt.title('Scatter plot of drinks vs alkphos')
plt.show()

# %%
# Plot the distribution of the data in both directions (x and y)
fig, axis = plt.subplots(1, 2, figsize=(16,6))

# Plot for drinks -> alkphos (X -> Y)
sns.histplot(df['drinks'], kde=True, ax=axis[0])
axis[0].set_xlabel('drinks')
axis[0].set_ylabel('alkphos')
axis[0].set_title('drinks distribution with KDE')

# Plot for alkphos -> drinks (Y -> X)
sns.histplot(df['alkphos'], kde=True, ax=axis[1])
axis[1].set_xlabel('alkphos')
axis[1].set_ylabel('drinks')
axis[1].set_title('alkphos distribution with KDE')

# Adjust layout to set the title and labels
plt.tight_layout()
plt.show()

# %%
# Dip-Test for x and y
dip_test, p_val = diptest(np.array(df['drinks']))
print(f"Dip-Test (X  → Y): {dip_test}, p-value: {p_val}")   
dip_test, p_val = diptest(np.array(df['alkphos']))
print(f"Dip-Test (Y  → X): {dip_test}, p-value: {p_val}")
# Out:
# Dip-Test (X  → Y): 0.07246376811594205, p-value: 0.0
# Dip-Test (Y  → X): 0.019047619047619042, p-value: 0.557515466904425

# %% [markdown]
# ### Findings:
# - The ground truth relationship is X → Y
# - The dip test results suggest that the distribution of X → Y is likely **multimodal**, supported by a low p-value 0.
# - While the distribution of Y → X direction is **unimodal**, supported by a high p-value 0.55.
