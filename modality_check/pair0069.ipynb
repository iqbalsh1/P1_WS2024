# %% [markdown]
# ## pair0069:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from diptest import diptest

# %%
df = pd.read_csv('datasets/pair0069.txt', sep=r'\s+', header=None, names=['X', 'Y'])

# %%
# Display few rows of the dataset
print(df.head())
# Out:
#       X     Y
# 0  19.0  21.0
# 1  19.0  20.5
# 2  18.5  16.5
# 3  18.5  15.0
# 4  18.5  14.0

# %%
scatter = plt.scatter(
    df['X'], 
    df['Y'], 
    c=df['Y'],  # Color based on Y values
    cmap='viridis',  
    alpha=0.6,  # Transparency for overlapping points
    edgecolor='k',  
    s=50  # Marker size
)

# Add labels and title
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Plot the distribution of the data
fig, axis = plt.subplots(1, 2, figsize=(16, 6))

# Plot for X
sns.histplot(df['X'], kde=True, bins=10, color='blue', ax=axis[0], alpha=0.6)
axis[0].set_title('Distribution of X')
axis[0].set_xlabel('X')
axis[0].set_ylabel('Density')

# Plot for Y
sns.histplot(df['Y'], kde=True, bins=20, color='green', ax=axis[1], alpha=0.6)
axis[1].set_title('Distribution of Y')
axis[1].set_xlabel('Y')
axis[1].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
def check_modality(column_name, data, threshold=0.05):
    dip_test, p_val = diptest(data)
    if p_val < threshold:
        print(f"Dip-Test ({column_name}): {dip_test}, p-value: {p_val} -> Multimodal")
    else:
        print(f"Dip-Test ({column_name}): {dip_test}, p-value: {p_val} -> Unimodal")

check_modality("X", np.array(df['X']))
check_modality("Y", np.array(df['Y']))
# Out:
# Dip-Test (X): 0.05692223171773898, p-value: 0.0 -> Multimodal
# Dip-Test (Y): 0.020076913685752654, p-value: 0.0 -> Multimodal
